# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
a=pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/movie_embd.csv')

# %%
a=pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/movie_embd.csv')
# Out:
# <ipython-input-22-cb9746cd0ba3>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   a=pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/movie_embd.csv')

# %%
a.head(1)
# Out:
#    Unnamed: 0          userId  movieId  rating_movie  verified  \
# 0           0  A2CFV9UPFTTM10  5419263           5.0       1.0
#
#    score_also_buy  score_also_view           movie_item_embedding
# 0          0.0476           0.0488  [1.0, 0.3163, 0.2029, 0.5205]

# %%
chunk_size = 10000  # Adjust this based on your available memory
chunks1 = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/user_embd.csv', chunksize=chunk_size)
chunks2 = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/movie_embd.csv', chunksize=chunk_size)

merged_chunks = []

for chunk1, chunk2 in zip(chunks1, chunks2):
    merged_chunk = pd.merge(chunk1, chunk2, on='userId', how='outer')
    merged_chunks.append(merged_chunk)

movie_final = pd.concat(merged_chunks)

# %%
movie_final.head(1)
# Out:
#    Unnamed: 0_x          userId              user_embedding  Unnamed: 0_y  \
# 0           0.0  A30TK6U7DNS82R  [0.0041, 0.0, 0.1111, 0.0]        1477.0
#
#      movieId  rating_movie  verified  score_also_buy  score_also_view  \
# 0  767803434           4.0       0.0          0.2381           0.0488
#
#              movie_item_embedding
# 0  [0.819, 0.045, 0.8205, 0.5205]

# %%
movie_final.to_csv('/content/drive/MyDrive/OBJ3_CROSS/New Dataset/book_final.csv')

# %%
chunk_size = 10000  # Adjust this based on your available memory
chunks1 = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/New Dataset/df_book_encoding.csv', chunksize=chunk_size)
chunks2 = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/Final_amazon_movie_encodding.csv', chunksize=chunk_size)

merged_chunks = []

for chunk1, chunk2 in zip(chunks1, chunks2):
    merged_chunk = pd.merge(chunk1, chunk2, on='userId', how='outer')
    merged_chunks.append(merged_chunk)

movie_final = pd.concat(merged_chunks)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-7bd2248f4582> in <cell line: 7>()
#       6
#       7 for chunk1, chunk2 in zip(chunks1, chunks2):
# ----> 8     merged_chunk = pd.merge(chunk1, chunk2, on='userId', how='outer')
#       9     merged_chunks.append(merged_chunk)
#      10
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
# ...

# %%
movie_final.shape
# Out:
# (413683, 13)

# %%
movie_final.shape
# Out:
# (771358, 10)

# %%
movie_final.head(1)
# Out:
#    Unnamed: 0_x  overall verified      reviewerID                     style  \
# 0           0.0      5.0     True  A2M1CU2IRZG0K9  {'Format:': ' VHS Tape'}
#
#   vote        asin  Unnamed: 0_y        also_buy                      rank  \
# 0  NaN  0005089549          20.0  ['B00M45SW04']  679,734 in Movies & TV (
#
#   also_view  similar_item                                              price
# 0        []           NaN  .a-box-inner{background-color:#fff}#alohaBuyBo...

# %%
movie_final = movie_final.drop_duplicates()

# %%
movie_final = movie_final[['userId','movieId','rating_movie','movie_item_embedding','user_embedding']]

# %%
movie_final.to_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/movie.csv')

# %%
book = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/book.csv')
movie = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/movie.csv')

# %%
amazon_book = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/New Dataset/df_book_encoding.csv')
amazon_movie = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/music_whole_final.csv')
# Out:
# <ipython-input-3-51a70fabe060>:2: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   amazon_movie = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/music_whole_final.csv')

# %%
amazon_book.head(1)
# Out:
#    Unnamed: 0      itemId  Price         userId  help  rating  score_category  \
# 0           0  1882931173    NaN  AVCGYZL8FQQTD   7.0     4.0        0.146341
#
#    publisher_FBE  authors_FBE
# 0            NaN          1.0

# %%
amazon_book.drop(columns=['Unnamed: 0'], inplace=True)
amazon_movie.drop(columns=['Unnamed: 0'], inplace=True)

# %%
amazon_book.shape, amazon_movie.shape
# Out:
# ((2755835, 8), (1068775, 10))

# %%
amazon_movie = amazon_movie.drop_duplicates()
amazon_book = amazon_book.drop_duplicates()

# %%
amazon_book.shape, amazon_movie.shape
# Out:
# ((2698758, 8), (808523, 10))

# %%
amazon_movie = amazon_movie.rename(columns={'reviewerID': 'userId'})

# %%
amazon_movie =amazon_movie[['userId','verified','score_also_buy','score_also_view']]

# %%
amazon_book =amazon_book[['userId','help']]

# %%
amazon_movie = amazon_movie.drop_duplicates()
amazon_book = amazon_book.drop_duplicates()

# %%
amazon_book.dtypes
# Out:
# userId     object
# help      float64
# dtype: object

# %%
amazon_book['userId'].nunique()
# Out:
# 1008972

# %%
amazon_book['userId'] = amazon_book['userId'].str.extract('(\d+)').astype(float)
amazon_movie['userId'] = amazon_movie['userId'].str.extract('(\d+)').astype(float)

# %%
amazon_book = amazon_book.set_index('userId')
amazon_movie = amazon_movie.set_index('userId')
amazon_book_movie = amazon_book.merge(amazon_movie, left_index=True, right_index=True)

# %%
amazon_book_movie = pd.merge(amazon_book, amazon_movie, on='userId', how='inner')

# %%
amazon_book_movie.head(1)
# Out:
#            userId  help  verified  score_also_buy  score_also_view
# 0  A30TK6U7DNS82R  10.0       0.0        0.238095          0.04878

# %%
from sklearn import preprocessing
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model, load_model

# %%
features1 = [f for f in amazon_book_movie.columns if f not in ['userId']]
features1
for feat in features1:
  lbl_enc = preprocessing.LabelEncoder()
  amazon_book_movie.loc[:, feat] = lbl_enc.fit_transform(amazon_book_movie[feat].astype(str).fillna("-1").values)
# Out:
# <ipython-input-17-185b372c541f>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   amazon_book_movie.loc[:, feat] = lbl_enc.fit_transform(amazon_book_movie[feat].astype(str).fillna("-1").values)
# <ipython-input-17-185b372c541f>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   amazon_book_movie.loc[:, feat] = lbl_enc.fit_transform(amazon_book_movie[feat].astype(str).fillna("-1").values)
# ...

# %%
features1
# Out:
# ['help', 'verified', 'score_also_buy', 'score_also_view']

# %%
amazon_book_movie['help'] = (amazon_book_movie['help']-amazon_book_movie['help'].min())/(amazon_book_movie['help'].max()-amazon_book_movie['help'].min())
amazon_book_movie['verified'] = (amazon_book_movie['verified']-amazon_book_movie['verified'].min())/(amazon_book_movie['verified'].max()-amazon_book_movie['verified'].min())
amazon_book_movie['score_also_buy'] = (amazon_book_movie['score_also_buy']-amazon_book_movie['score_also_buy'].min())/(amazon_book_movie['score_also_buy'].max()-amazon_book_movie['score_also_buy'].min())
amazon_book_movie['score_also_view'] = (amazon_book_movie['score_also_view']-amazon_book_movie['score_also_view'].min())/(amazon_book_movie['score_also_view'].max()-amazon_book_movie['score_also_view'].min())

# %%
amazon_book_movie.head(1)
# Out:
#            userId      help  verified  score_also_buy  score_also_view
# 0  A30TK6U7DNS82R  0.004115       0.0        0.111111              0.0

# %%
amazon_book_movie.shape
# Out:
# (680465, 5)

# %%
amazon_book_movie = amazon_book_movie.round(decimals=4)

# %%
amazon_book_movie = amazon_book_movie.fillna(0)

# %%
amazon_book_movie['user_embedding']  = amazon_book_movie.apply(lambda x: list([x['help'],
                                        x['verified'],
                                        x['score_also_buy'],x['score_also_view']]),axis=1)

# %%
amazon_book_movie = amazon_book_movie[['userId','user_embedding']]

# %%
amazon_book_movie.to_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/user_embd.csv')

# %%
user = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/user_embd.csv')

# %%
book = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/New Dataset/df_book_encoding.csv')

# %%
movie = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/movie_embd.csv')
# Out:
# <ipython-input-36-91efa816b500>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/movie_embd.csv')

# %%
book = book[['userId','itemId','rating','book_item_embedding']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-9d5739d38036> in <cell line: 1>()
# ----> 1 book = book[['userId','itemId','rating','book_item_embedding']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
book = book[['userId','movieId','rating_movie','movie_item_embedding']]

# %%
book.head(1)
# Out:
#    Unnamed: 0      itemId  Price         userId  help  rating  score_category  \
# 0           0  1882931173    NaN  AVCGYZL8FQQTD   7.0     4.0        0.146341
#
#    publisher_FBE  authors_FBE
# 0            NaN          1.0

# %%
user.shape, book.shape
# Out:
# ((680465, 3), (2755835, 9))

# %%
user = user.drop_duplicates()
book = book.drop_duplicates()

# %%
user.shape, book.shape
# Out:
# ((680465, 3), (2755835, 9))

# %%
book = pd.merge(user, book, on='userId', how='inner')

# %%
features1 = [f for f in book.columns if f not in ['Unnamed: 0',	'itemId',		'userId',	'help'	,'rating']]
features1
for feat in features1:
  lbl_enc = preprocessing.LabelEncoder()
  book.loc[:, feat] = lbl_enc.fit_transform(book[feat].astype(str).fillna("-1").values)
# Out:
# <ipython-input-14-3a4e06107fd9>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   book.loc[:, feat] = lbl_enc.fit_transform(book[feat].astype(str).fillna("-1").values)
# <ipython-input-14-3a4e06107fd9>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   book.loc[:, feat] = lbl_enc.fit_transform(book[feat].astype(str).fillna("-1").values)
# ...

# %%
features1
# Out:
# ['Price', 'score_category', 'publisher_FBE', 'authors_FBE']

# %%
book['Price'] = (book['Price']-book['Price'].min())/(book['Price'].max()-book['Price'].min())
book['score_category'] = (book['score_category']-book['score_category'].min())/(book['score_category'].max()-book['score_category'].min())
book['publisher_FBE'] = (book['publisher_FBE']-book['publisher_FBE'].min())/(book['publisher_FBE'].max()-book['publisher_FBE'].min())
book['authors_FBE'] = (book['authors_FBE']-book['authors_FBE'].min())/(book['authors_FBE'].max()-book['authors_FBE'].min())

# %%
book = book.round(decimals=4)

# %%
book = book.fillna(0)

# %%
book['book_embedding']  = book.apply(lambda x: list([x['Price'],
                                        x['score_category'],
                                        x['publisher_FBE'],x['authors_FBE']]),axis=1)

# %%
book.head(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-90a8eece9de8> in <cell line: 1>()
# ----> 1 book.head(1)
#
# NameError: name 'book' is not defined

# %%
book.to_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/book_embeding.csv')

# %%
user = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/user_embd.csv')

# %%
book = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/book_embeding.csv')

# %%
user.head(1)
# Out:
#            userId              user_embedding
# 0  A30TK6U7DNS82R  [0.0041, 0.0, 0.1111, 0.0]

# %%
user = user[['userId','user_embedding']]

# %%
book = book[['userId','itemId','rating','book_embedding']]

# %%
amazon_movie = amazon_movie.drop_duplicates()
amazon_book = amazon_book.drop_duplicates()

# %%
amazon_book_movie.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5bce7c52b4a9> in <cell line: 1>()
# ----> 1 amazon_book_movie.shape
#
# NameError: name 'amazon_book_movie' is not defined

# %%
amazon_movie.sort_values(by='userId', inplace=True)
amazon_book.sort_values(by='userId', inplace=True)
#amazon_book_movie = pd.merge(amazon_movie, amazon_book, on='userId')

# %%
amazon_book_movie = amazon_movie.merge(amazon_book, how='cross')

# %%
amazon_book_movie = pd.merge(amazon_movie, amazon_book, on=['userId'], how='inner')

# %%
amazon_book_movie.head(1)
# Out:
#            userId  verified  score_also_buy  score_also_view  help
# 0  A3TS9EQCNLU0SM       1.0        0.047619          0.04878   3.0

# %%
from sklearn import preprocessing
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model, load_model

# %%
features2 = [f for f in amazon_book_movie.columns if f not in ['userId']]
features2
for feat in features2:
  lbl_enc = preprocessing.LabelEncoder()
  amazon_book_movie.loc[:, feat] = lbl_enc.fit_transform(amazon_book_movie[feat].astype(str).fillna("-1").values)
# Out:
# <ipython-input-18-7b8ef7122501>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   amazon_book_movie.loc[:, feat] = lbl_enc.fit_transform(amazon_book_movie[feat].astype(str).fillna("-1").values)
# <ipython-input-18-7b8ef7122501>:5: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   amazon_book_movie.loc[:, feat] = lbl_enc.fit_transform(amazon_book_movie[feat].astype(str).fillna("-1").values)
# ...

# %%
features2
# Out:
# ['verified', 'score_also_buy', 'score_also_view', 'help']

# %%
amazon_book_movie['verified'] = (amazon_book_movie['verified']-amazon_book_movie['verified'].min())/(amazon_book_movie['verified'].max()-amazon_book_movie['verified'].min())
amazon_book_movie['score_also_buy'] = (amazon_book_movie['score_also_buy']-amazon_book_movie['score_also_buy'].min())/(amazon_book_movie['score_also_buy'].max()-amazon_book_movie['score_also_buy'].min())
amazon_book_movie['score_also_view'] = (amazon_book_movie['score_also_view']-amazon_book_movie['score_also_view'].min())/(amazon_book_movie['score_also_view'].max()-amazon_book_movie['score_also_view'].min())
amazon_book_movie['help'] = (amazon_book_movie['help']-amazon_book_movie['help'].min())/(amazon_book_movie['help'].max()-amazon_book_movie['help'].min())

# %%
amazon_book_movie = amazon_book_movie.round(decimals=4)

# %%
amazon_book_movie = amazon_book_movie.fillna(0)

# %%
amazon_book_movie['user_embedding']  = amazon_book_movie.apply(lambda x: list([x['verified'],
                                        x['score_also_buy'],
                                        x['score_also_view'],x['help']]),axis=1)

# %%
df.head(1)
# Out:
#        itemId         userId  rating   book_item_embedding
# 0  1882931173  AVCGYZL8FQQTD     4.0  [1.0, 0.5, 1.0, 0.0]

# %%
df = pd.read_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/book_embd.csv')

# %%
df = df[['itemId',	'userId',	'rating',	'book_item_embedding']]

# %%
amazon_book_movie = amazon_book_movie[['userId','user_embedding']]

# %%
book_embd = pd.merge(df, amazon_book_movie, on=['userId'], how='inner')

# %%
book_embd.to_csv('/content/drive/MyDrive/OBJ3_CROSS/MOVIE-BOOK/book_final.csv')
